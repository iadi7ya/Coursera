# %% [markdown]
# # Warmup Assignment 2
# Below you see some ApacheSpark code written in Python. You don't have to change code now, the only thing we want you to do is to make sure that you have a proper Apache Spark Notebook environment available for this course

# %%
def assignment1(sc):
    rdd = sc.parallelize(range(100))
    return rdd.count()
# Out:
# Waiting for a Spark session to start...
# Spark Initialization Done! ApplicationId = app-20191031082500-0000
# KERNEL_ID = e8047bd0-a40e-40c2-a4c3-59ae9c06b369

# %%
print(assignment1(sc))
# Out:
# 100

# %%
# !rm -f rklib.py
# !wget https://raw.githubusercontent.com/IBM/coursera/master/rklib.py
# Out:
# --2019-10-31 08:25:23--  https://raw.githubusercontent.com/IBM/coursera/master/rklib.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.60.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.60.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2540 (2.5K) [text/plain]
# Saving to: 'rklib.py'
#
# 100%[======================================>] 2,540       --.-K/s   in 0s
#
# 2019-10-31 08:25:23 (32.1 MB/s) - 'rklib.py' saved [2540/2540]

# %% [markdown]
# Please provide your email address and obtain a submission token on the grader’s submission page in coursera, then execute the cell

# %%
from rklib import submit
import json

key = "R1eDmiHNEei9kxIYdin0mA"
part = "fnFg7"
email = 'iadi7ya@gmail.com'
token = 'RcWe0Q7HDpqKeLzU'


submit(email, token, key, part, [part], json.dumps(assignment1(sc)))
# Out:
# Submission successful, please check on the coursera grader page for the status
# -------------------------
# {"elements":[{"itemId":"D277m","id":"sUpST4RAEeawAApvKZgcCQ~D277m~Frkvzfu4Eemv7QpEPVe5Gw","courseId":"sUpST4RAEeawAApvKZgcCQ"}],"paging":{},"linked":{}}
# -------------------------
